# %%
#Feature Hashing

hasher = FeatureHasher(n_features = 10, input_type='string')
df['destination_cities'].toarray()

# %%
cost of the products, weight in gms

kmaens(cluters = 3, random_state = 42)

kmeans.fit_transform(cost of the products, weight in gms)

# %%
col = cost_of_the _product and the weight_in_gms.fillna(0)
var = K-menas(clusters = 3, random_state = 42)
s = var.fit_tranform(col)
print("Distance of 3 shipments or shipping profiles

# %%
select = SelectKbest(scorefunction=f_classif,k=2)
X = df[["cost of the product,weight in gms,discount offered, customer tating"]]
select = select.fit_tranform(X,y)
select.get_support(indeces=True)

# %%
s = RandomForestClassifier(n_estimator=50)
embed = SelectFromModel(s,treshold='median')
embed.fit(X_clean,y)
print(embedselector.get_support())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s = RandomForestClassifier(n_estimator=50)
#       2 embed = SelectFromModel(s,treshold='median')
#       3 embed.fit(X_clean,y)
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
pcs = PCA(n_components=2)
s = pcs.fit_transform(X_clean)
peint(s.shape())
print(x_clean.shape())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pcs = PCA(n_components=2)
#       2 s = pcs.fit_transform(X_clean)
#       3 peint(s.shape())
#
# NameError: name 'PCA' is not defined
