# %% [markdown]
# <a href="https://colab.research.google.com/github/mailech/ShipmentSure-Predicting-On-Time-Delivery-Using-Supplier-Data/blob/ShipmentSure_Sukritha/EDA_Day1_Sukritha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
