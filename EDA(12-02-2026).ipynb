# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importing dataset

# %%
data=pd.read_csv('Train.csv')

# %% [markdown]
# Pivot

# %%
data1=data.pivot_table(values='Customer_rating',index='Warehouse_block',columns='Mode_of_Shipment')
data1
# Out:
# Mode_of_Shipment    Flight      Road      Ship
# Warehouse_block
# A                 3.288462  2.634921  3.024390
# B                 2.650000  3.123077  3.000000
# C                 3.132353  3.012987  2.913043
# D                 2.985507  2.814286  2.824324
# F                 3.054795  3.271429  3.000000

# %% [markdown]
# Unique values in Warehouse

# %%
data['Warehouse_block'].unique()
# Out:
# array(['C', 'F', 'B', 'A', 'D'], dtype=object)

# %% [markdown]
# Values using logical operations product importance - high

# %%
df=data[data['Product_importance']=='high']['Discount_offered'].mean()
df
# Out:
# 30.91304347826087

# %% [markdown]
# Value Counts

# %%
data['Cost_of_the_Product'].value_counts()
# Out:
# Cost_of_the_Product
# 273    12
# 170    11
# 189    10
# 121     9
# 154     9
#        ..
# 287     1
# 266     1
# 124     1
# 301     1
# 90      1
# Name: count, Length: 220, dtype: int64

# %%
data['Weight_in_gms'].value_counts()
# Out:
# Weight_in_gms
# 1722    4
# 2847    3
# 5027    3
# 2147    3
# 2431    3
#        ..
# 3495    1
# 4560    1
# 5155    1
# 2615    1
# 1304    1
# Name: count, Length: 903, dtype: int64

# %% [markdown]
# Mean of Cost of Product

# %%
data['Cost_of_the_Product'].mean()
# Out:
# 200.316

# %% [markdown]
# Values greater than mean of cost of the product

# %%
df=data[data['Cost_of_the_Product']>data['Cost_of_the_Product'].mean()]
df
# Out:
#        ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0       1               C           Flight                    2
# 2       3               B             Ship                    7
# 5       6               F             Road                    5
# 6       7               D           Flight                    5
# 8       9               C           Flight                    2
# ..    ...             ...              ...                  ...
# 989   990               C             Road                    7
# 991   992               C             Road                    4
# 992   993               D             Road                    4
# 998   999               A             Road                    5
# 999  1000               B           Flight                    6
#
#      Customer_rating  Cost_of_the_Product  Prior_purchases Product_importance  \
# 0                  5                  306                6               high
# ...

# %% [markdown]
# Finding number of values length

# %%
len(df)
# Out:
# 509
