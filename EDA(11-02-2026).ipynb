# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing dataset

# %%
data=pd.read_csv('Train.csv')

# %% [markdown]
# Calculating Skew

# %%
data['Cost_of_the_Product'].skew()
# Out:
# -0.020104832239605342

# %%
data['Weight_in_gms'].skew()
# Out:
# -0.05898565460773562

# %% [markdown]
# Mean

# %%
data['Cost_of_the_Product'].mean()
# Out:
# 200.316

# %%
data['Weight_in_gms'].mean()
# Out:
# 3501.413

# %% [markdown]
# Median

# %%
data['Cost_of_the_Product'].median()
# Out:
# 202.5

# %%
data['Weight_in_gms'].median()
# Out:
# 3544.0

# %% [markdown]
# Mode

# %%
data['Cost_of_the_Product'].mode()
# Out:
# 0    273
# Name: Cost_of_the_Product, dtype: int64

# %%
data['Weight_in_gms'].mode()
# Out:
# 0    1722
# Name: Weight_in_gms, dtype: int64
