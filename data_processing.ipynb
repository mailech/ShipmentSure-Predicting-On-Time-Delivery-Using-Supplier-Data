# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Train.csv")
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               C           Flight                    2                5
# 1   2               F             Ship                    7                2
# 2   3               B             Ship                    7                2
# 3   4               A             Road                    5                3
# 4   5               F             Ship                    3                5
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  306                6               high      M
# 1                  114                3               high      M
# 2                  215                7             medium      F
# 3                  126                5             medium      M
# 4                  113                3             medium      M
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                45           3838                    1
# 1                35           2710                    1
# 2                44           4152                    0
# 3                54           2245                    0
# 4                43           1806                    1

# %%
df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
X= df.drop('Reached.on.Time_Y.N',axis=1)
y=df['Reached.on.Time_Y.N']
print("Features shape:",X.shape)
print("Target shape:",y.shape)
# Out:
# Features shape: (1000, 11)
# Target shape: (1000,)

# %%
categorical_columns=X.select_dtypes(include='object').columns
categorical_columns
# Out:
# Index(['Warehouse_block', 'Mode_of_Shipment', 'Product_importance', 'Gender'], dtype='object')

# %%
X_encoded=pd.get_dummies(X,drop_first=True)
X_encoded.head()
# Out:
#    ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# 0   1                    2                5                  306
# 1   2                    7                2                  114
# 2   3                    7                2                  215
# 3   4                    5                3                  126
# 4   5                    3                5                  113
#
#    Prior_purchases  Discount_offered  Weight_in_gms  Warehouse_block_B  \
# 0                6                45           3838              False
# 1                3                35           2710              False
# 2                7                44           4152               True
# 3                5                54           2245              False
# 4                3                43           1806              False
#
#    Warehouse_block_C  Warehouse_block_D  Warehouse_block_F  \
# 0               True              False              False
# 1              False              False               True
# 2              False              False              False
# 3              False              False              False
# 4              False              False               True
#
#    Mode_of_Shipment_Road  Mode_of_Shipment_Ship  Product_importance_low  \
# 0                  False                  False                   False
# 1                  False                   True                   False
# 2                  False                   True                   False
# 3                   True                  False                   False
# 4                  False                   True                   False
#
#    Product_importance_medium  Gender_M
# 0                      False      True
# 1                      False      True
# 2                       True     False
# 3                       True      True
# 4                       True      True

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X_encoded)
X_scaled=pd.DataFrame(X_scaled,columns=X_encoded.columns)
X_scaled.head()
# Out:
#          ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# 0 -1.730320            -1.458242         1.418235             1.685582
# 1 -1.726856             1.431655        -0.689098            -1.376677
# 2 -1.723391             1.431655        -0.689098             0.234199
# 3 -1.719927             0.275696         0.013346            -1.185286
# 4 -1.716463            -0.880263         1.418235            -1.392626
#
#    Prior_purchases  Discount_offered  Weight_in_gms  Warehouse_block_B  \
# 0         0.006219          0.703501       0.239186          -0.468521
# 1        -1.159787          0.162887      -0.562394          -0.468521
# 2         0.394887          0.649440       0.462321           2.134375
# 3        -0.382450          1.190054      -0.892833          -0.468521
# 4        -1.159787          0.595378      -1.204796          -0.468521
#
#    Warehouse_block_C  Warehouse_block_D  Warehouse_block_F  \
# 0            1.91648          -0.520238          -0.493742
# 1           -0.52179          -0.520238           2.025350
# 2           -0.52179          -0.520238          -0.493742
# 3           -0.52179          -0.520238          -0.493742
# 4           -0.52179          -0.520238           2.025350
#
#    Mode_of_Shipment_Road  Mode_of_Shipment_Ship  Product_importance_low  \
# 0              -0.725753              -0.706577               -0.738644
# 1              -0.725753               1.415275               -0.738644
# 2              -0.725753               1.415275               -0.738644
# 3               1.377879              -0.706577               -0.738644
# 4              -0.725753               1.415275               -0.738644
#
#    Product_importance_medium  Gender_M
# 0                  -0.693889  1.032529
# 1                  -0.693889  1.032529
# 2                   1.441153 -0.968496
# 3                   1.441153  1.032529
# 4                   1.441153  1.032529

# %%
X_scaled['Target']=y
X_scaled.head()
# Out:
#          ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# 0 -1.730320            -1.458242         1.418235             1.685582
# 1 -1.726856             1.431655        -0.689098            -1.376677
# 2 -1.723391             1.431655        -0.689098             0.234199
# 3 -1.719927             0.275696         0.013346            -1.185286
# 4 -1.716463            -0.880263         1.418235            -1.392626
#
#    Prior_purchases  Discount_offered  Weight_in_gms  Warehouse_block_B  \
# 0         0.006219          0.703501       0.239186          -0.468521
# 1        -1.159787          0.162887      -0.562394          -0.468521
# 2         0.394887          0.649440       0.462321           2.134375
# 3        -0.382450          1.190054      -0.892833          -0.468521
# 4        -1.159787          0.595378      -1.204796          -0.468521
#
#    Warehouse_block_C  Warehouse_block_D  Warehouse_block_F  \
# 0            1.91648          -0.520238          -0.493742
# 1           -0.52179          -0.520238           2.025350
# 2           -0.52179          -0.520238          -0.493742
# 3           -0.52179          -0.520238          -0.493742
# 4           -0.52179          -0.520238           2.025350
#
#    Mode_of_Shipment_Road  Mode_of_Shipment_Ship  Product_importance_low  \
# 0              -0.725753              -0.706577               -0.738644
# 1              -0.725753               1.415275               -0.738644
# 2              -0.725753               1.415275               -0.738644
# 3               1.377879              -0.706577               -0.738644
# 4              -0.725753               1.415275               -0.738644
#
#    Product_importance_medium  Gender_M  Target
# 0                  -0.693889  1.032529       1
# 1                  -0.693889  1.032529       1
# 2                   1.441153 -0.968496       0
# 3                   1.441153  1.032529       0
# 4                   1.441153  1.032529       1

# %%
X_scaled.to_csv("preprocessed_data.csv",index=False)
